# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [09:26, 55.4KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1,window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'input')
    labels = tf.placeholder(tf.int32, [None,1], name = 'input')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding),-1,1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev = 0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                     labels, embed,
                                     n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
batches = get_batches(train_words, batch_size, window_size)
batches
# Out:
# <generator object get_batches at 0x154c23150>

# %%
window_size
# Out:
# 10

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6339 0.2282 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6387 0.2329 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5039 0.2340 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6069 0.2353 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4993 0.2384 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5346 0.2391 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5547 0.2376 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5803 0.2332 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4909 0.2346 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4074 0.2304 sec/batch
# Nearest to d: rachmaninoff, skeptics, aerated, rahxephon, pluck, aldgate, byronic, coaxial,
# Nearest to world: bessus, amaranthus, germano, schleicher, discernable, punisher, memorial, ajaccio,
# Nearest to all: scotia, morel, rhymed, macromolecule, orlando, spell, balti, mckenzie,
# Nearest to only: batman, alluded, someday, within, summarily, telegrams, roller, bassline,
# Nearest to if: hugging, computers, barbie, westernmost, khalq, estas, coherence, proceeds,
# Nearest to more: moto, mauss, gyrus, galatasaray, boney, int, riddled, reaffirmed,
# Nearest to where: seductress, physiologist, parlay, naci, divisor, milwaukee, briscoe, guest,
# Nearest to by: completes, conceits, narain, profess, lightened, zoe, harding, kostas,
# Nearest to articles: rockstar, dissatisfied, cyan, internationalist, greenwood, therese, sympathy, paulinus,
# Nearest to ice: uttar, remakes, orrin, poetics, nonspecific, peri, turbocharger, defeating,
# Nearest to magazine: krieg, breakthrough, fontsize, roslin, sue, flammarion, secluded, destroy,
# Nearest to egypt: canton, lmp, centered, waveform, families, danny, defeats, morningside,
# Nearest to freedom: qinghai, thames, ral, cookbooks, abolished, incomprehensible, erupt, czechoslovakian,
# Nearest to instance: arcology, undocumented, founding, fructose, fraunhofer, zhuang, dhimmi, mchugh,
# Nearest to san: ans, tibet, illegitimacy, discreetly, actually, hallucination, perverse, chattel,
# Nearest to account: tear, countless, cayuga, anthology, tomography, monomyth, macbeth, promenade,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4950 0.2329 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3789 0.2438 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3426 0.2256 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2697 0.2232 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1495 0.2369 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1660 0.2473 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0874 0.2365 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0435 0.2240 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0197 0.2244 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9983 0.2395 sec/batch
# Nearest to d: skeptics, use, potentially, regulus, rachmaninoff, aerated, confederation, combos,
# Nearest to world: met, memorial, devices, amaranthus, itself, dictatorships, downey, germano,
# Nearest to all: scotia, spell, indicated, orlando, morel, however, rhymed, jury,
# Nearest to only: within, batman, someday, telegrams, effect, movement, alluded, virtually,
# Nearest to if: computers, proceeds, hugging, khalq, ign, understand, malaysians, mixture,
# Nearest to more: int, mauss, portable, appeared, galatasaray, trade, simplest, moto,
# Nearest to where: guest, divisor, bent, indeed, ronald, trends, physiologist, sister,
# Nearest to by: completes, you, narain, harding, lightened, conceits, wild, profess,
# Nearest to articles: rockstar, dissatisfied, hugo, uninhabited, cyan, kilometres, qassam, rhombic,
# Nearest to ice: uttar, remakes, orrin, poetics, liberate, defeating, chef, doubt,
# Nearest to magazine: breakthrough, kidnap, krieg, destroy, sue, harold, genitals, flammarion,
# Nearest to egypt: canton, centered, families, lmp, waveform, defeats, outlines, sacked,
# Nearest to freedom: qinghai, thames, abolished, ral, cookbooks, incomprehensible, erupt, magnifying,
# Nearest to instance: founding, undocumented, independent, savage, fired, blanton, arcology, fraunhofer,
# Nearest to san: tibet, actually, ans, pgs, perverse, hallucination, discreetly, illegitimacy,
# Nearest to account: tear, countless, cayuga, tomography, anthology, brummell, macbeth, promenade,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9391 0.2411 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8911 0.2312 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8671 0.2322 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8593 0.2288 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8194 0.2395 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8120 0.2326 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7822 0.2313 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7842 0.2440 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8099 0.2358 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7609 0.2363 sec/batch
# Nearest to d: skeptics, arisen, coaxial, confederation, aldgate, rachmaninoff, aerated, sindhu,
# Nearest to world: met, memorial, folio, germano, amaranthus, regent, parliament, downey,
# Nearest to all: scotia, indicated, spell, rhymed, morel, orlando, mckenzie, macromolecule,
# Nearest to only: batman, within, alluded, someday, hilly, effect, educating, telegrams,
# Nearest to if: computers, proceeds, hugging, mixture, estas, khalq, ign, understand,
# Nearest to more: int, mauss, gyrus, reaffirmed, galatasaray, moto, chat, portable,
# Nearest to where: divisor, guest, ronald, bulk, physiologist, parlay, trends, bent,
# Nearest to by: completes, you, narain, harding, lightened, profess, conceits, indifferent,
# Nearest to articles: dissatisfied, uninhabited, rockstar, hugo, kilometres, austrian, tai, helicopters,
# Nearest to ice: uttar, remakes, poetics, defeating, liberate, orrin, subdivision, doubt,
# Nearest to magazine: breakthrough, kidnap, destroy, harold, krieg, sue, committee, flammarion,
# Nearest to egypt: canton, centered, waveform, defeats, lmp, families, sacked, outlines,
# Nearest to freedom: abolished, qinghai, thames, ral, cookbooks, aren, incomprehensible, bribery,
# Nearest to instance: founding, undocumented, savage, arcology, fraunhofer, independent, blanton, fired,
# Nearest to san: tibet, ans, actually, pgs, perverse, illegitimacy, alexandra, blade,
# Nearest to account: tear, countless, cayuga, anthology, tomography, chairman, vs, macbeth,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7406 0.2366 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7600 0.2255 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7203 0.2268 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7092 0.2231 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7633 0.2258 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7106 0.2256 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6891 0.2259 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7263 0.2241 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7181 0.2455 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6564 0.2363 sec/batch
# Nearest to d: physiologist, coaxial, skeptics, aldgate, pe, affections, eight, sindhu,
# Nearest to world: met, folio, bessus, memorial, downey, amaranthus, germano, regent,
# Nearest to all: scotia, morel, indicated, rhymed, spell, macromolecule, mckenzie, rages,
# Nearest to only: batman, roller, telegrams, alluded, someday, summarily, within, hilly,
# Nearest to if: proceeds, computers, estas, hugging, mixture, khalq, barbie, ign,
# Nearest to more: moto, avert, mauss, int, galatasaray, reaffirmed, gyrus, riddled,
# Nearest to where: divisor, physiologist, bulk, carve, parlay, guest, bristol, bent,
# Nearest to by: completes, narain, conceits, profess, indifferent, lightened, crew, you,
# Nearest to articles: dissatisfied, rockstar, uninhabited, austrian, greenwood, tai, qassam, helicopters,
# Nearest to ice: uttar, orrin, shipwrecked, subdivision, remakes, liberate, poetics, mirage,
# Nearest to magazine: breakthrough, harold, kidnap, krieg, destroy, committee, flammarion, sue,
# Nearest to egypt: canton, defeats, centered, waveform, lmp, sacked, families, interlinked,
# Nearest to freedom: ral, qinghai, abolished, cookbooks, thames, incomprehensible, erupt, aren,
# Nearest to instance: undocumented, founding, arcology, fructose, savage, blanton, telekom, fraunhofer,
# Nearest to san: ans, tibet, illegitimacy, alexandra, pgs, two, actually, herstory,
# Nearest to account: tear, cayuga, countless, anthology, tomography, chairman, monomyth, macbeth,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6734 0.2371 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6538 0.2351 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6204 0.2474 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6398 0.2394 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6291 0.2396 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6318 0.2386 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6045 0.1705 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5460 0.2390 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5165 0.2407 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5210 0.2410 sec/batch
# Nearest to d: physiologist, eight, coaxial, jules, guitarist, de, painter, aldgate,
# Nearest to world: met, memorial, folio, bessus, regent, amaranthus, downey, maxim,
# Nearest to all: rhymed, spell, indicated, mckenzie, rages, kondratiev, macromolecule, morel,
# Nearest to only: roller, batman, telegrams, alluded, summarily, effect, someday, within,
# Nearest to if: proceeds, computers, understand, estas, correspond, ign, malaysians, coherence,
# Nearest to more: moto, avert, galatasaray, mauss, damages, gyrus, int, reaffirmed,
# Nearest to where: bulk, divisor, carve, guest, naci, parlay, bristol, marshallese,
# Nearest to by: narain, conceits, profess, completes, indifferent, lightened, demos, crew,
# Nearest to articles: dissatisfied, rockstar, greenwood, tai, uninhabited, austrian, internationalist, qassam,
# Nearest to ice: uttar, orrin, shipwrecked, subdivision, remakes, dragoons, mirage, ivo,
# Nearest to magazine: harold, breakthrough, kidnap, destroy, krieg, itinerarium, flammarion, committee,
# Nearest to egypt: canton, defeats, waveform, centered, sacked, lmp, interlinked, families,
# Nearest to freedom: ral, abolished, erupt, cookbooks, qinghai, augusti, thames, incomprehensible,
# Nearest to instance: undocumented, fructose, telekom, founding, blanton, fraunhofer, fleshed, arcology,
# Nearest to san: ans, tibet, alexandra, illegitimacy, two, pgs, amit, herstory,
# Nearest to account: tear, countless, cayuga, anthology, tomography, monomyth, chairman, criticism,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5055 0.2459 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4988 0.2419 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4580 0.2352 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5174 0.2330 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4798 0.2287 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4664 0.2286 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4382 0.2283 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4463 0.2318 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4258 0.2371 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4209 0.2351 sec/batch
# Nearest to d: physiologist, rachmaninoff, jules, aldgate, coaxial, arnold, skeptics, brock,
# Nearest to world: met, memorial, folio, amaranthus, regent, punisher, bessus, downey,
# Nearest to all: indicated, rhymed, kondratiev, spell, rages, macromolecule, gf, mandaeanism,
# Nearest to only: roller, summarily, alluded, batman, effect, telegrams, traverse, someday,
# Nearest to if: proceeds, computers, understand, beowulf, correspond, estas, malaysians, mixture,
# Nearest to more: damages, mauss, avert, int, moto, newest, galatasaray, gyrus,
# Nearest to where: divisor, bulk, carve, guest, parlay, briscoe, evolutions, bristol,
# Nearest to by: narain, completes, conceits, profess, indifferent, lightened, boldly, matic,
# Nearest to articles: rockstar, dissatisfied, tai, greenwood, austrian, uninhabited, sympathy, internationalist,
# Nearest to ice: orrin, shipwrecked, dragoons, uttar, subdivision, ivo, mirage, remakes,
# Nearest to magazine: harold, itinerarium, kidnap, breakthrough, flammarion, wtoo, krieg, destroy,
# Nearest to egypt: canton, defeats, sacked, centered, waveform, consecrate, persecutions, creed,
# Nearest to freedom: ral, erupt, abolished, cookbooks, augusti, qinghai, entitle, thames,
# Nearest to instance: telekom, undocumented, fructose, blanton, arcology, secretory, uniquely, fleshed,
# Nearest to san: ans, alexandra, tibet, two, amit, herstory, pgs, illegitimacy,
# Nearest to account: tear, countless, cayuga, anthology, criticism, promenade, upsets, chairman,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4220 0.2423 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4163 0.2359 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4319 0.2310 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3518 0.2524 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4261 0.2418 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4354 0.2394 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4039 0.2382 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3843 0.2292 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4080 0.2314 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3658 0.2285 sec/batch
# Nearest to d: physiologist, rachmaninoff, jules, aldgate, butler, skeptics, arnold, caron,
# Nearest to world: met, memorial, amaranthus, bessus, folio, regent, downey, oecd,
# Nearest to all: indicated, macromolecule, kondratiev, gf, mckenzie, mandaeanism, asean, spell,
# Nearest to only: roller, batman, summarily, effect, someday, telegrams, concretely, traverse,
# Nearest to if: proceeds, beowulf, correspond, estas, computers, ign, genome, malaysians,
# Nearest to more: avert, damages, gyrus, mauss, moto, costly, write, int,
# Nearest to where: divisor, carve, naci, spatially, evolutions, terre, briscoe, physiologist,
# Nearest to by: narain, completes, conceits, profess, indifferent, boldly, hiroshi, unparalleled,
# Nearest to articles: rockstar, tai, dissatisfied, austrian, greenwood, uninhabited, internationalist, skulls,
# Nearest to ice: orrin, dragoons, shipwrecked, subdivision, ivo, mirage, remakes, uttar,
# Nearest to magazine: harold, itinerarium, kidnap, breakthrough, krieg, wtoo, flammarion, magnifying,
# Nearest to egypt: canton, defeats, sacked, persecutions, centered, waveform, interlinked, consecrate,
# Nearest to freedom: ral, erupt, cookbooks, entitle, abolished, zalta, augusti, betters,
# Nearest to instance: telekom, uniquely, fructose, infinitely, undocumented, fleshed, fraunhofer, arcology,
# Nearest to san: ans, two, tibet, alexandra, exarch, illegitimacy, herstory, amit,
# Nearest to account: tear, countless, cayuga, anthology, criticism, tomography, promenade, upsets,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3684 0.2371 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4124 0.2458 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3695 0.2272 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3685 0.2339 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3736 0.2324 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3654 0.2332 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3830 0.2314 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3974 0.2311 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3502 0.2384 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3302 0.2261 sec/batch
# Nearest to d: physiologist, rachmaninoff, ag, regulus, aldgate, rahxephon, jules, skeptics,
# Nearest to world: eked, met, amaranthus, downey, memorial, folio, bessus, radiocommunication,
# Nearest to all: indicated, macromolecule, gf, asean, kondratiev, mckenzie, sierpinski, enix,
# Nearest to only: roller, batman, effect, summarily, concretely, alluded, preordained, educating,
# Nearest to if: proceeds, beowulf, genome, exactly, estas, correspond, t, computers,
# Nearest to more: damages, gyrus, avert, mauss, moto, deleting, write, newest,
# Nearest to where: divisor, carve, naci, physiologist, briscoe, evolutions, terre, divisible,
# Nearest to by: narain, profess, completes, conceits, newly, secretary, unparalleled, kostas,
# Nearest to articles: rockstar, dissatisfied, tai, hugo, greenwood, austrian, internationalist, rhombic,
# Nearest to ice: dragoons, subdivision, shipwrecked, orrin, ivo, mirage, varna, remakes,
# Nearest to magazine: harold, itinerarium, breakthrough, kidnap, krieg, wtoo, magnifying, flammarion,
# Nearest to egypt: canton, defeats, sacked, centered, persecutions, antiquity, waveform, interlinked,
# Nearest to freedom: entitle, ral, cookbooks, erupt, abolished, zalta, augusti, franco,
# Nearest to instance: fructose, telekom, undocumented, arcology, infinitely, uniquely, fraunhofer, fleshed,
# Nearest to san: ans, exarch, alexandra, tibet, two, illegitimacy, pgs, amit,
# Nearest to account: tear, countless, cayuga, anthology, criticism, divinity, tomography, promenade,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3474 0.2378 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3099 0.2414 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3811 0.2426 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3765 0.2395 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3805 0.2379 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2788 0.2356 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3123 0.2421 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3125 0.2588 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2277 0.2753 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3010 0.2417 sec/batch
# Nearest to d: physiologist, rachmaninoff, butler, caron, jules, b, de, regulus,
# Nearest to world: memorial, eked, clubs, met, downey, amaranthus, radiocommunication, populaire,
# Nearest to all: indicated, macromolecule, kondratiev, mandaeanism, gf, mckenzie, sierpinski, enix,
# Nearest to only: roller, summarily, batman, effect, concretely, alluded, locus, strategy,
# Nearest to if: proceeds, beowulf, t, exactly, correspond, genome, concord, renderer,
# Nearest to more: damages, avert, gyrus, newest, deleting, moto, hel, write,
# Nearest to where: divisor, carve, naci, terre, divisible, briscoe, thoroughgoing, evolutions,
# Nearest to by: narain, profess, completes, secretary, conceits, newly, hiroshi, kostas,
# Nearest to articles: rockstar, tai, dissatisfied, hugo, internationalist, com, austrian, greenwood,
# Nearest to ice: subdivision, dragoons, shipwrecked, ivo, mirage, orrin, varna, remakes,
# Nearest to magazine: itinerarium, harold, breakthrough, wtoo, kidnap, krieg, llewelyn, flammarion,
# Nearest to egypt: canton, defeats, persecutions, centered, sacked, antiquity, waveform, interlinked,
# Nearest to freedom: entitle, ral, cookbooks, erupt, social, abolished, zalta, escalate,
# Nearest to instance: fructose, uniquely, fleshed, infinitely, telekom, undocumented, fraunhofer, vector,
# Nearest to san: ans, exarch, alexandra, chattel, philadelphia, illegitimacy, pgs, tibet,
# Nearest to account: countless, tear, cayuga, anthology, criticism, promenade, divinity, indiction,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3020 0.2360 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3210 0.2312 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3285 0.0975 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2526 0.2380 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2439 0.2412 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2190 0.2434 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2149 0.2397 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2129 0.2407 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2138 0.2425 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1809 0.2417 sec/batch
# Nearest to d: rachmaninoff, physiologist, caron, ag, butler, regulus, aldgate, ramon,
# Nearest to world: eked, clubs, memorial, downey, amaranthus, radiocommunication, populaire, television,
# Nearest to all: indicated, kondratiev, macromolecule, asean, gf, vis, mandaeanism, ddr,
# Nearest to only: roller, summarily, batman, effect, endeavours, lovable, strategy, traverse,
# Nearest to if: proceeds, beowulf, t, exactly, concord, genome, tegmark, renderer,
# Nearest to more: damages, hel, avert, write, gyrus, deleting, mauss, intension,
# Nearest to where: terre, carve, naci, briscoe, divisor, divisible, thorn, a,
# Nearest to by: narain, profess, completes, hiroshi, kostas, newly, ii, damme,
# Nearest to articles: rockstar, tai, dissatisfied, austrian, com, hugo, internationalist, greenwood,
# Nearest to ice: subdivision, dragoons, ivo, shipwrecked, mirage, orrin, remakes, varna,
# Nearest to magazine: itinerarium, kidnap, harold, breakthrough, krieg, flammarion, wtoo, llewelyn,
# Nearest to egypt: defeats, canton, antiquity, persecutions, centered, waveform, sacked, speedily,
# Nearest to freedom: entitle, ral, erupt, social, zalta, abolished, cookbooks, escalate,
# Nearest to instance: uniquely, arcology, fructose, fleshed, mentioned, infinitely, undocumented, founding,
# Nearest to san: ans, exarch, chattel, pgs, amit, oberlin, philadelphia, tibet,
# Nearest to account: countless, tear, cayuga, anthology, infant, divinity, criticism, indiction,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2394 0.2425 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2394 0.2394 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2350 0.2425 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1291 0.2387 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1888 0.2357 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1728 0.2443 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1500 0.2302 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1665 0.2559 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1865 0.2509 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1927 0.2433 sec/batch
# Nearest to d: rachmaninoff, physiologist, ag, regulus, caron, x, rahxephon, aldgate,
# Nearest to world: eked, clubs, amaranthus, memorial, oecd, populaire, television, radiocommunication,
# Nearest to all: indicated, kondratiev, gf, macromolecule, vis, polynomial, asean, sierpinski,
# Nearest to only: roller, effect, batman, summarily, strategy, traverse, with, endeavours,
# Nearest to if: proceeds, exactly, called, t, beowulf, genome, sum, renderer,
# Nearest to more: damages, deleting, gyrus, intension, write, dynamically, chat, mauss,
# Nearest to where: divisor, naci, divisible, carve, terre, briscoe, a, parlay,
# Nearest to by: completes, narain, hiroshi, profess, kostas, referrals, keillor, solution,
# Nearest to articles: com, tai, rockstar, detailed, austrian, greenwood, dissatisfied, hugo,
# Nearest to ice: subdivision, dragoons, ivo, shipwrecked, mirage, orrin, remakes, varna,
# Nearest to magazine: itinerarium, kidnap, harold, wtoo, llewelyn, krieg, breakthrough, ceo,
# Nearest to egypt: defeats, antiquity, canton, persecutions, waveform, centered, muhammad, speedily,
# Nearest to freedom: entitle, social, ral, erupt, zalta, abolished, cookbooks, taking,
# Nearest to instance: fructose, uniquely, telekom, infinitely, fleshed, order, permutations, telekinesis,
# Nearest to san: ans, exarch, philadelphia, chattel, pgs, oberlin, amit, victoria,
# Nearest to account: countless, tear, cayuga, anthology, infant, divinity, indiction, promenade,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1780 0.2482 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2238 0.2392 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1903 0.2418 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1628 0.2399 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1869 0.2390 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1816 0.2275 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1940 0.2310 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1655 0.2329 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1103 0.2508 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1784 0.2484 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, caron, regulus, aldgate, ramon, rahxephon,
# Nearest to world: clubs, eked, amaranthus, memorial, television, populaire, series, internacia,
# Nearest to all: indicated, gf, kondratiev, asean, vis, macromolecule, ldcs, however,
# Nearest to only: roller, effect, with, strategy, batman, declension, concretely, summarily,
# Nearest to if: proceeds, exactly, called, t, renderer, beowulf, sum, tegmark,
# Nearest to more: deleting, damages, gyrus, intension, avert, mauss, newest, write,
# Nearest to where: divisor, terre, naci, divisible, carve, x, briscoe, fsm,
# Nearest to by: narain, kostas, completes, hiroshi, zoe, solution, donahue, newly,
# Nearest to articles: com, tai, detailed, website, rockstar, https, quarterly, entry,
# Nearest to ice: subdivision, dragoons, ivo, shipwrecked, orrin, varna, mirage, remakes,
# Nearest to magazine: itinerarium, kidnap, harold, krieg, wtoo, llewelyn, flammarion, breakthrough,
# Nearest to egypt: canton, antiquity, defeats, waveform, persecutions, centered, olaf, speedily,
# Nearest to freedom: entitle, erupt, taking, social, ral, escalate, zalta, abolished,
# Nearest to instance: uniquely, fructose, fleshed, arcology, founding, telekinesis, logik, order,
# Nearest to san: ans, exarch, pgs, oberlin, chattel, philadelphia, del, illegitimacy,
# Nearest to account: countless, tear, anthology, infant, cayuga, indiction, divinity, promenade,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1801 0.2390 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1776 0.2346 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1796 0.2285 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2112 0.2345 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1180 0.2319 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1254 0.2261 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1600 0.2226 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1140 0.2299 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1770 0.2281 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2162 0.2200 sec/batch
# Nearest to d: rachmaninoff, physiologist, ag, caron, b, ramon, psychologist, de,
# Nearest to world: clubs, eked, amaranthus, populaire, television, memorial, downey, tarleton,
# Nearest to all: indicated, vis, gf, asean, macromolecule, kondratiev, however, sack,
# Nearest to only: roller, effect, declension, summarily, batman, concretely, traverse, strategy,
# Nearest to if: proceeds, exactly, renderer, beowulf, called, nominating, tegmark, hearing,
# Nearest to more: odos, deleting, avert, gyrus, nominee, intension, newest, mauss,
# Nearest to where: terre, briscoe, naci, carve, divisible, divisor, a, guest,
# Nearest to by: narain, kostas, hiroshi, newly, profess, zoe, prosecutions, ii,
# Nearest to articles: com, tai, website, detailed, https, entry, hugo, rockstar,
# Nearest to ice: subdivision, dragoons, ivo, orrin, shipwrecked, varna, remakes, helier,
# Nearest to magazine: itinerarium, kidnap, flammarion, llewelyn, krieg, wtoo, breakthrough, harold,
# Nearest to egypt: canton, antiquity, defeats, olaf, centered, sacked, persecutions, waveform,
# Nearest to freedom: entitle, ral, escalate, taking, zalta, social, erupt, drew,
# Nearest to instance: arcology, founding, logik, fleshed, mentioned, telekinesis, uniquely, undocumented,
# Nearest to san: ans, exarch, oberlin, pgs, chattel, francisco, philadelphia, actually,
# Nearest to account: countless, tear, indiction, anthology, cayuga, divinity, infant, promenade,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2389 0.2261 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1276 0.2204 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1357 0.2164 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1334 0.2187 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0564 0.2183 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1142 0.2224 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1291 0.2182 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1283 0.2251 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1659 0.0311 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1300 0.2455 sec/batch
# Nearest to d: rachmaninoff, physiologist, ag, caron, ramon, regulus, dedekind, b,
# Nearest to world: clubs, eked, amaranthus, series, television, populaire, memorial, maxim,
# Nearest to all: gf, indicated, macromolecule, kondratiev, vis, asean, however, sierpinski,
# Nearest to only: roller, effect, traverse, batman, with, concretely, summarily, declension,
# Nearest to if: proceeds, exactly, hearing, tegmark, called, will, renderer, sum,
# Nearest to more: odos, deleting, avert, nominee, write, limewire, damages, newest,
# Nearest to where: a, terre, carve, divisible, divisor, briscoe, naci, chav,
# Nearest to by: kostas, zoe, solution, narain, hiroshi, donahue, ii, newly,
# Nearest to articles: com, detailed, website, entry, https, tai, org, rockstar,
# Nearest to ice: subdivision, dragoons, ivo, remakes, shipwrecked, orrin, helier, varna,
# Nearest to magazine: kidnap, flammarion, wtoo, itinerarium, krieg, llewelyn, harold, breakthrough,
# Nearest to egypt: canton, antiquity, olaf, defeats, persecutions, canaan, waveform, centered,
# Nearest to freedom: entitle, escalate, social, zalta, erupt, taking, ral, torrens,
# Nearest to instance: founding, fleshed, arcology, telekinesis, uniquely, mentioned, fructose, logik,
# Nearest to san: ans, francisco, exarch, oberlin, philadelphia, chattel, ceuta, pgs,
# Nearest to account: countless, tear, indiction, cayuga, theatrics, infant, anthology, wirtschaftswunder,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0813 0.2245 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0715 0.2437 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1044 0.2390 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0798 0.2366 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0940 0.2290 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0541 0.2243 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1063 0.2286 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0920 0.2383 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1126 0.2329 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0188 0.2328 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, caron, regulus, ramon, dedekind, pe,
# Nearest to world: clubs, series, eked, amaranthus, fiesta, athletics, television, populaire,
# Nearest to all: gf, macromolecule, indicated, kondratiev, vis, asean, polynomial, however,
# Nearest to only: roller, effect, traverse, declension, concretely, with, strategy, endeavours,
# Nearest to if: proceeds, exactly, called, t, renderer, tegmark, divisor, sum,
# Nearest to more: deleting, newest, santorini, odos, write, ensue, intension, deserved,
# Nearest to where: terre, a, briscoe, carve, naci, divisible, divisor, parlay,
# Nearest to by: kostas, zoe, solution, narain, hiroshi, ii, newly, adopting,
# Nearest to articles: com, entry, https, tai, detailed, org, website, html,
# Nearest to ice: subdivision, ivo, dragoons, remakes, shipwrecked, helier, orrin, varna,
# Nearest to magazine: flammarion, kidnap, wtoo, itinerarium, llewelyn, krieg, overview, harold,
# Nearest to egypt: antiquity, canton, waveform, olaf, canaan, tanakh, persecutions, centered,
# Nearest to freedom: entitle, zalta, torrens, ral, erupt, escalate, social, franco,
# Nearest to instance: mentioned, uniquely, telekinesis, arcology, order, founding, undocumented, ritz,
# Nearest to san: francisco, ans, exarch, oberlin, philadelphia, pgs, ceuta, chattel,
# Nearest to account: countless, tear, infant, cayuga, indiction, theatrics, wirtschaftswunder, zucker,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0515 0.2373 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0025 0.2325 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0418 0.2247 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0648 0.2365 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0500 0.2320 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0493 0.2339 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0385 0.2333 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1078 0.2256 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0614 0.2342 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0515 0.2231 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, regulus, caron, dedekind, pe, ramon,
# Nearest to world: clubs, series, amaranthus, eked, television, fiesta, maxim, memorial,
# Nearest to all: gf, asean, vis, macromolecule, kondratiev, polynomial, sierpinski, however,
# Nearest to only: effect, roller, with, traverse, strategy, concretely, parthenogenesis, legislatures,
# Nearest to if: proceeds, then, exactly, called, t, divisor, will, sum,
# Nearest to more: deleting, nominee, newest, intension, limewire, ssh, gyrus, odos,
# Nearest to where: a, divisor, briscoe, carve, terre, divisible, naci, fsm,
# Nearest to by: kostas, hiroshi, solution, zoe, narain, donahue, adopting, though,
# Nearest to articles: com, website, https, entry, detailed, org, external, tai,
# Nearest to ice: subdivision, dragoons, ivo, remakes, shipwrecked, varna, helier, mirage,
# Nearest to magazine: kidnap, llewelyn, flammarion, itinerarium, wtoo, krieg, overview, harold,
# Nearest to egypt: antiquity, canton, olaf, waveform, canaan, centered, interlinked, speedily,
# Nearest to freedom: entitle, torrens, escalate, zalta, franco, taking, social, monopolistic,
# Nearest to instance: uniquely, mentioned, order, founding, arcology, telekinesis, ritz, undocumented,
# Nearest to san: francisco, ans, philadelphia, del, oberlin, exarch, beekeeping, ceuta,
# Nearest to account: countless, tear, indiction, infant, cayuga, wirtschaftswunder, bondage, zucker,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0623 0.2356 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0690 0.2282 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0731 0.2290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0883 0.2220 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0931 0.2326 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0236 0.2251 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0446 0.2275 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0800 0.2275 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1054 0.2305 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0525 0.2377 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, caron, regulus, ramon, dedekind, bor,
# Nearest to world: clubs, series, eked, amaranthus, internacia, fiesta, television, maxim,
# Nearest to all: asean, gf, vis, however, macromolecule, indicated, kondratiev, polynomial,
# Nearest to only: effect, roller, kifl, declension, batman, legislatures, concretely, traverse,
# Nearest to if: proceeds, exactly, then, will, called, hearing, divides, renderer,
# Nearest to more: odos, deleting, nominee, avert, ensue, precious, gyrus, santorini,
# Nearest to where: terre, briscoe, a, carve, naci, divisor, divisible, ascertained,
# Nearest to by: of, dynastic, kostas, narain, solution, adopting, brothel, though,
# Nearest to articles: com, entry, website, detailed, external, https, tai, org,
# Nearest to ice: subdivision, dragoons, ivo, remakes, semiautomatic, mirage, shipwrecked, helier,
# Nearest to magazine: kidnap, overview, flammarion, llewelyn, wtoo, itinerarium, krieg, harold,
# Nearest to egypt: canton, olaf, antiquity, canaan, idris, waveform, centered, speedily,
# Nearest to freedom: entitle, torrens, zalta, franco, taking, escalate, social, erupt,
# Nearest to instance: uniquely, founding, ritz, arcology, telekinesis, order, mentioned, fructose,
# Nearest to san: francisco, ans, oberlin, marina, del, exarch, philadelphia, beekeeping,
# Nearest to account: countless, tear, infant, bondage, indiction, wirtschaftswunder, cayuga, theatrics,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0270 0.2495 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0443 0.2340 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0288 0.2403 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0793 0.2359 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0515 0.2252 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1113 0.2281 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1248 0.2286 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0436 0.2273 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0159 0.2282 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0609 0.2278 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, regulus, caron, bor, alva, ramon,
# Nearest to world: clubs, eked, series, amaranthus, internacia, tarleton, fiesta, maxim,
# Nearest to all: gf, however, asean, vis, kondratiev, macromolecule, indicated, polynomial,
# Nearest to only: roller, effect, batman, kifl, traverse, declension, parthenogenesis, legislatures,
# Nearest to if: proceeds, exactly, then, t, will, called, statements, follows,
# Nearest to more: avert, nominee, odos, deserved, limewire, deleting, write, gyrus,
# Nearest to where: a, terre, briscoe, carve, divisor, thoroughgoing, divisible, ascertained,
# Nearest to by: of, kostas, solution, donahue, narain, newly, adopting, dynastic,
# Nearest to articles: com, entry, website, external, detailed, https, tai, org,
# Nearest to ice: subdivision, dragoons, ivo, remakes, invertebrate, semiautomatic, helier, shout,
# Nearest to magazine: kidnap, flammarion, wtoo, llewelyn, overview, itinerarium, harold, secluded,
# Nearest to egypt: olaf, antiquity, canton, canaan, idris, waveform, tanakh, centered,
# Nearest to freedom: entitle, torrens, zalta, social, escalate, taking, franco, monopolistic,
# Nearest to instance: founding, ritz, uniquely, mentioned, conjugations, arcology, telekinesis, order,
# Nearest to san: francisco, ans, marina, oberlin, exarch, philadelphia, del, beekeeping,
# Nearest to account: countless, tear, wirtschaftswunder, indiction, bondage, cayuga, infant, salaam,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9820 0.2266 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0138 0.2242 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0435 0.2317 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0267 0.2348 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0822 0.2369 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0446 0.1955 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0075 0.2345 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9954 0.2300 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0247 0.2288 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9574 0.2282 sec/batch
# Nearest to d: rachmaninoff, ag, physiologist, caron, regulus, alva, bor, ramon,
# Nearest to world: clubs, series, eked, amaranthus, internacia, fiesta, wis, maxim,
# Nearest to all: gf, asean, vis, however, kondratiev, polynomial, macromolecule, indicated,
# Nearest to only: roller, effect, legislatures, parthenogenesis, batman, traverse, alms, kifl,
# Nearest to if: proceeds, exactly, then, hearing, nominating, statements, will, anyone,
# Nearest to more: odos, millennium, deserved, deleting, write, limewire, elamites, curule,
# Nearest to where: briscoe, a, terre, locality, carve, and, ascertained, divisible,
# Nearest to by: of, zoe, kostas, though, adopting, dynastic, a, solution,
# Nearest to articles: com, entry, external, website, tai, detailed, report, greenwood,
# Nearest to ice: subdivision, ivo, dragoons, remakes, invertebrate, semiautomatic, shout, mirage,
# Nearest to magazine: kidnap, flammarion, llewelyn, wtoo, overview, initialization, secluded, fontsize,
# Nearest to egypt: canaan, antiquity, olaf, idris, waveform, canton, tanakh, centered,
# Nearest to freedom: entitle, zalta, torrens, social, escalate, erupt, drew, cookbooks,
# Nearest to instance: mentioned, ritz, arcology, founding, order, conjugations, uniquely, telekinesis,
# Nearest to san: francisco, marina, ans, oberlin, exarch, maranh, del, beekeeping,
# Nearest to account: countless, wirtschaftswunder, bondage, tear, indiction, sorcerers, infant, cayuga,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9806 0.2326 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9623 0.2315 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0069 0.2337 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0119 0.2332 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0261 0.2367 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9884 0.2332 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8939 0.2353 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9682 0.2324 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9528 0.2288 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9515 0.2310 sec/batch
# Nearest to d: rachmaninoff, ag, regulus, caron, physiologist, alva, bor, republika,
# Nearest to world: clubs, series, eked, amaranthus, internacia, fiesta, oecd, athletics,
# Nearest to all: gf, vis, however, asean, in, polynomial, kondratiev, macromolecule,
# Nearest to only: roller, effect, legislatures, parthenogenesis, traverse, with, batman, strategy,
# Nearest to if: proceeds, exactly, called, bijection, then, divisor, statements, follows,
# Nearest to more: newest, nominee, odos, deleting, deserved, greatest, ensue, millennium,
# Nearest to where: a, briscoe, locality, ascertained, parlay, divisor, terre, carve,
# Nearest to by: of, a, zoe, solution, kostas, adopting, donahue, though,
# Nearest to articles: com, entry, external, tai, detailed, website, report, html,
# Nearest to ice: subdivision, ivo, dragoons, remakes, invertebrate, semiautomatic, mirage, helier,
# Nearest to magazine: flammarion, kidnap, llewelyn, wtoo, overview, secluded, harold, initialization,
# Nearest to egypt: canaan, antiquity, olaf, idris, waveform, canton, egyptian, tanakh,
# Nearest to freedom: torrens, entitle, zalta, social, monopolistic, franco, superficial, erupt,
# Nearest to instance: mentioned, order, arcology, conjugations, ritz, uniquely, founding, fructose,
# Nearest to san: francisco, marina, del, maranh, ans, oberlin, philadelphia, ceuta,
# Nearest to account: countless, tear, wirtschaftswunder, indiction, cayuga, infant, bondage, occ,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9944 0.2323 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9937 0.2307 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9565 0.2287 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0158 0.2294 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0374 0.2327 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9519 0.2350 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9636 0.2266 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9911 0.2275 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9846 0.2302 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9912 0.2320 sec/batch
# Nearest to d: rachmaninoff, ag, caron, regulus, physiologist, alva, bor, mosby,
# Nearest to world: clubs, series, internacia, amaranthus, eked, athletics, television, wis,
# Nearest to all: gf, vis, asean, in, however, kondratiev, macromolecule, ellipsis,
# Nearest to only: roller, effect, legislatures, with, legally, parthenogenesis, kifl, traverse,
# Nearest to if: proceeds, exactly, then, will, called, nominating, anyone, statements,
# Nearest to more: nominee, deleting, solicit, deserved, ensue, millennium, odos, limewire,
# Nearest to where: a, briscoe, locality, ascertained, parlay, carve, guest, include,
# Nearest to by: of, a, adopting, zoe, though, in, dynastic, as,
# Nearest to articles: com, entry, external, detailed, website, online, html, tai,
# Nearest to ice: subdivision, ivo, dragoons, remakes, invertebrate, semiautomatic, shout, mirage,
# Nearest to magazine: flammarion, llewelyn, kidnap, overview, wtoo, harold, secluded, krieg,
# Nearest to egypt: olaf, canaan, waveform, antiquity, canton, idris, egyptian, interlinked,
# Nearest to freedom: torrens, entitle, zalta, superficial, taking, monopolistic, holder, social,
# Nearest to instance: order, mentioned, ritz, founding, uniquely, arcology, fructose, lyapunov,
# Nearest to san: francisco, del, marina, ans, maranh, camelot, oberlin, jose,
# Nearest to account: countless, wirtschaftswunder, tear, indiction, bondage, infant, occ, cayuga,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0198 0.2387 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9763 0.2333 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9809 0.2340 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0356 0.2342 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0028 0.2353 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9939 0.2284 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0008 0.2280 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9567 0.2333 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9605 0.2307 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9995 0.2292 sec/batch
# Nearest to d: rachmaninoff, ag, regulus, caron, bor, alva, physiologist, mosby,
# Nearest to world: clubs, series, eked, amaranthus, internacia, athletics, maxim, television,
# Nearest to all: gf, vis, asean, however, macromolecule, in, kondratiev, ellipsis,
# Nearest to only: roller, effect, legally, kifl, legislatures, traverse, alms, gentoo,
# Nearest to if: proceeds, exactly, then, called, will, let, minis, not,
# Nearest to more: deleting, nominee, odos, millennium, precious, gyrus, deserved, limewire,
# Nearest to where: briscoe, locality, a, divisor, ascertained, thoroughgoing, baa, carve,
# Nearest to by: of, dynastic, a, in, adopting, zoe, as, kostas,
# Nearest to articles: com, entry, external, report, tai, website, detailed, greenwood,
# Nearest to ice: subdivision, ivo, dragoons, remakes, invertebrate, semiautomatic, proterozoic, alegre,
# Nearest to magazine: overview, flammarion, wtoo, kidnap, llewelyn, krieg, initialization, fontsize,
# Nearest to egypt: canaan, olaf, antiquity, waveform, idris, egyptian, canton, accords,
# Nearest to freedom: torrens, entitle, zalta, taking, cookbooks, superficial, holder, harming,
# Nearest to instance: ritz, mentioned, arcology, founding, order, uniquely, conjugations, blazon,
# Nearest to san: francisco, del, marina, ans, maranh, camelot, exarch, beekeeping,
# Nearest to account: countless, cayuga, indiction, wirtschaftswunder, bondage, tear, accounts, brummell,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9818 0.2313 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0854 0.2315 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0392 0.2342 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0382 0.2312 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9498 0.2301 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9459 0.2353 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.0113 0.2330 sec/batch
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8883 0.2192 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8284 0.2236 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8552 0.2186 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9301 0.2187 sec/batch
# Nearest to d: rachmaninoff, mosby, rennie, bor, caron, regulus, ag, getz,
# Nearest to world: series, analyst, other, maxim, internacia, related, nine, diamondbacks,
# Nearest to all: in, gf, are, for, of, asean, however, haba,
# Nearest to only: more, to, with, also, the, legislatures, reduced, not,
# Nearest to if: proceeds, then, exactly, not, called, limitations, any, a,
# Nearest to more: only, are, most, with, for, than, nominee, iic,
# Nearest to where: briscoe, a, include, locality, the, to, and, ascertained,
# Nearest to by: of, a, in, the, as, with, and, is,
# Nearest to articles: com, entry, detailed, report, external, allafrica, shor, wikis,
# Nearest to ice: subdivision, pressure, proterozoic, ivo, remakes, malthus, pechenegs, amylase,
# Nearest to magazine: news, kidnap, flammarion, lomborg, initialization, archives, secluded, bruun,
# Nearest to egypt: egyptian, accords, canaan, idris, waveform, olaf, antiquity, centered,
# Nearest to freedom: torrens, harming, superficial, reductionism, holder, watchman, liberty, entitle,
# Nearest to instance: blazon, ritz, turntable, lyapunov, quoting, insertafter, tyres, arma,
# Nearest to san: francisco, maranh, jose, conservatorio, marina, viejo, diego, camelot,
# Nearest to account: accounts, troop, occ, tear, expedition, zucker, supposing, wirtschaftswunder,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8343 0.2206 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8420 0.2178 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8711 0.2196 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8402 0.2181 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8622 0.2185 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9095 0.2192 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8546 0.2209 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8382 0.2191 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8948 0.2196 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8607 0.2384 sec/batch
# Nearest to d: rachmaninoff, caron, mosby, bor, rennie, getz, regulus, ag,
# Nearest to world: series, nine, internacia, other, maxim, related, analyst, in,
# Nearest to all: in, are, for, gf, of, asean, vis, however,
# Nearest to only: to, legislatures, more, also, legally, with, not, it,
# Nearest to if: proceeds, exactly, not, then, limitations, called, payable, any,
# Nearest to more: are, most, only, nominee, hygienic, greatest, found, rarest,
# Nearest to where: briscoe, include, locality, ascertained, amora, a, offensives, prepares,
# Nearest to by: of, a, in, the, as, and, which, though,
# Nearest to articles: com, entry, external, detailed, report, wikis, website, allafrica,
# Nearest to ice: subdivision, proterozoic, pressure, remakes, ivo, malthus, pechenegs, invertebrate,
# Nearest to magazine: news, flammarion, lomborg, initialization, archives, kidnap, article, overview,
# Nearest to egypt: egyptian, accords, canaan, waveform, idris, olaf, antiquity, centered,
# Nearest to freedom: torrens, harming, holder, entitle, superficial, reductionism, albanians, purveyor,
# Nearest to instance: blazon, ritz, arcology, lyapunov, charybdis, pubic, fructose, order,
# Nearest to san: francisco, maranh, conservatorio, marina, jose, viejo, camelot, exarch,
# Nearest to account: accounts, zero, troop, large, occ, expedition, recounts, wirtschaftswunder,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8523 0.2370 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8428 0.2334 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8637 0.2342 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8168 0.2323 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9021 0.2340 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8353 0.2306 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9434 0.2335 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9261 0.2324 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9154 0.2334 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8511 0.2390 sec/batch
# Nearest to d: rachmaninoff, caron, getz, mosby, rennie, bor, regulus, psychologist,
# Nearest to world: nine, internacia, of, related, series, other, in, maxim,
# Nearest to all: in, are, for, gf, of, however, asean, vis,
# Nearest to only: more, to, legislatures, not, that, also, charted, with,
# Nearest to if: exactly, proceeds, not, then, limitations, payable, statements, nominating,
# Nearest to more: most, are, only, found, than, as, and, nominee,
# Nearest to where: briscoe, include, locality, offensives, a, amora, ascertained, the,
# Nearest to by: of, a, in, as, the, is, which, and,
# Nearest to articles: com, entry, detailed, external, report, website, wikis, allafrica,
# Nearest to ice: subdivision, proterozoic, remakes, ivo, pressure, malthus, pechenegs, sheets,
# Nearest to magazine: news, flammarion, lomborg, initialization, magazines, article, kidnap, bruun,
# Nearest to egypt: egyptian, accords, canaan, waveform, idris, olaf, antiquity, centered,
# Nearest to freedom: torrens, harming, entitle, holder, liberty, purveyor, superficial, reductionism,
# Nearest to instance: blazon, ritz, charybdis, lyapunov, pubic, arcology, quoting, turntable,
# Nearest to san: francisco, maranh, conservatorio, viejo, jose, camelot, angeles, marina,
# Nearest to account: accounts, zero, troop, expedition, occ, indiction, wirtschaftswunder, samaria,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8029 0.2391 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8523 0.2335 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7929 0.2384 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8666 0.2357 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8683 0.2343 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8627 0.2315 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9025 0.0923 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8408 0.2345 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8107 0.2386 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8298 0.2337 sec/batch
# Nearest to d: rachmaninoff, caron, psychologist, getz, rennie, eight, mosby, bor,
# Nearest to world: maxim, series, nine, other, related, internacia, analyst, counter,
# Nearest to all: in, for, are, of, gf, vis, asean, however,
# Nearest to only: to, more, that, legislatures, few, also, the, copland,
# Nearest to if: proceeds, exactly, not, limitations, then, payable, statements, nominating,
# Nearest to more: most, are, only, found, has, with, greatest, nominee,
# Nearest to where: briscoe, locality, in, a, offensives, the, to, and,
# Nearest to by: of, a, in, the, as, is, which, and,
# Nearest to articles: entry, com, external, detailed, report, website, allafrica, wikis,
# Nearest to ice: subdivision, proterozoic, ivo, remakes, malthus, pressure, pechenegs, invite,
# Nearest to magazine: news, lomborg, flammarion, initialization, magazines, article, bruun, kidnap,
# Nearest to egypt: egyptian, accords, canaan, waveform, idris, olaf, antiquity, rameses,
# Nearest to freedom: torrens, harming, liberty, purveyor, entitle, zalta, holder, superficial,
# Nearest to instance: blazon, ritz, charybdis, pubic, turntable, lyapunov, gawain, quoting,
# Nearest to san: francisco, maranh, conservatorio, marina, jose, angeles, viejo, exarch,
# Nearest to account: accounts, expedition, recounts, troop, wirtschaftswunder, indiction, fomorians, bondage,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8636 0.2349 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7913 0.2361 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8341 0.2364 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7885 0.2327 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8176 0.2171 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8493 0.2165 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8825 0.2269 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7712 0.2261 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7815 0.2290 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8356 0.2374 sec/batch
# Nearest to d: rachmaninoff, caron, getz, mosby, regulus, rennie, pluck, gly,
# Nearest to world: nine, other, series, one, internacia, also, analyst, related,
# Nearest to all: in, are, for, gf, of, the, same, is,
# Nearest to only: to, more, also, with, the, that, are, not,
# Nearest to if: not, exactly, proceeds, then, called, a, any, limitations,
# Nearest to more: are, most, only, as, and, has, with, than,
# Nearest to where: a, in, briscoe, the, include, to, and, this,
# Nearest to by: a, of, in, the, as, which, is, with,
# Nearest to articles: entry, com, detailed, external, report, wikis, online, shor,
# Nearest to ice: subdivision, proterozoic, remakes, malthus, ivo, pressure, pechenegs, invite,
# Nearest to magazine: news, lomborg, flammarion, magazines, initialization, article, bruun, mitigation,
# Nearest to egypt: egyptian, accords, canaan, waveform, idris, olaf, antiquity, rameses,
# Nearest to freedom: torrens, harming, purveyor, liberty, holder, superficial, coe, zalta,
# Nearest to instance: blazon, ritz, quoting, gawain, charybdis, pubic, lyapunov, turntable,
# Nearest to san: francisco, maranh, jose, marina, conservatorio, angeles, camelot, narrows,
# Nearest to account: accounts, zero, expedition, troop, supercomputers, supposing, occ, ganga,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7516 0.2305 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8045 0.2268 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8647 0.2248 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8185 0.2334 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8181 0.2253 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8706 0.2243 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8531 0.2305 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7948 0.2293 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8428 0.2294 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8555 0.2294 sec/batch
# Nearest to d: rachmaninoff, mosby, caron, regulus, rennie, maupin, bor, getz,
# Nearest to world: nine, series, other, internacia, related, analyst, maxim, in,
# Nearest to all: in, are, of, for, gf, such, and, same,
# Nearest to only: to, not, more, also, the, that, few, with,
# Nearest to if: not, exactly, then, proceeds, called, limitations, any, invariants,
# Nearest to more: most, are, found, only, than, has, for, many,
# Nearest to where: briscoe, a, include, locality, this, keno, the, offensives,
# Nearest to by: of, a, in, the, as, which, with, and,
# Nearest to articles: entry, com, external, detailed, links, report, online, wikis,
# Nearest to ice: subdivision, proterozoic, remakes, pressure, malthus, ivo, pechenegs, invite,
# Nearest to magazine: news, magazines, lomborg, flammarion, initialization, bruun, article, birthday,
# Nearest to egypt: egyptian, accords, waveform, canaan, idris, interlinked, olaf, antiquity,
# Nearest to freedom: torrens, harming, liberty, libertarian, freedoms, purveyor, faire, indepth,
# Nearest to instance: blazon, ritz, gawain, charybdis, quoting, lyapunov, arcology, pubic,
# Nearest to san: francisco, maranh, jose, conservatorio, marina, camelot, viejo, bunghole,
# Nearest to account: accounts, expedition, troop, supercomputers, occ, discrepancies, supposing, large,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8552 0.2334 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8499 0.2392 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8188 0.2380 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8543 0.2280 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8371 0.2280 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8381 0.2346 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8375 0.2350 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8429 0.2396 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8115 0.2345 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8013 0.2333 sec/batch
# Nearest to d: rachmaninoff, bor, mosby, regulus, caron, e, pluck, maupin,
# Nearest to world: other, nine, internacia, series, related, maxim, analyst, see,
# Nearest to all: are, in, for, of, and, same, gf, such,
# Nearest to only: to, more, not, are, that, also, the, but,
# Nearest to if: not, exactly, then, proceeds, called, may, any, limitations,
# Nearest to more: are, most, as, only, than, found, with, for,
# Nearest to where: a, this, and, in, briscoe, the, include, to,
# Nearest to by: of, in, a, the, as, which, and, with,
# Nearest to articles: entry, com, external, detailed, report, wikis, website, allafrica,
# Nearest to ice: subdivision, proterozoic, remakes, ivo, malthus, pressure, pechenegs, invite,
# Nearest to magazine: news, magazines, lomborg, flammarion, initialization, article, bruun, birthday,
# Nearest to egypt: egyptian, accords, waveform, idris, canaan, interlinked, olaf, rameses,
# Nearest to freedom: torrens, harming, liberty, purveyor, encountering, freedoms, faire, zalta,
# Nearest to instance: blazon, gawain, ritz, charybdis, turntable, arcology, fructose, granites,
# Nearest to san: francisco, maranh, marina, conservatorio, jose, camelot, bunghole, marco,
# Nearest to account: accounts, zero, expedition, troop, supposing, supercomputers, occ, discrepancies,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8390 0.2320 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8207 0.2281 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8983 0.2347 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9273 0.2400 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9110 0.2309 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8339 0.2264 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7934 0.2206 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8437 0.2300 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7418 0.2282 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8731 0.2300 sec/batch
# Nearest to d: rachmaninoff, caron, getz, eight, regulus, bor, psychologist, mosby,
# Nearest to world: nine, internacia, maxim, other, stephanie, related, of, counter,
# Nearest to all: in, are, of, for, gf, such, a, has,
# Nearest to only: to, more, the, not, that, copland, a, are,
# Nearest to if: not, then, exactly, proceeds, limitations, do, must, statements,
# Nearest to more: are, most, as, than, only, has, with, found,
# Nearest to where: a, this, in, briscoe, and, to, the, locality,
# Nearest to by: of, a, in, the, as, and, which, is,
# Nearest to articles: entry, com, external, detailed, wikis, report, links, website,
# Nearest to ice: subdivision, proterozoic, remakes, malthus, pressure, ivo, pechenegs, invite,
# Nearest to magazine: news, magazines, lomborg, flammarion, initialization, article, birthday, bruun,
# Nearest to egypt: egyptian, accords, waveform, canaan, idris, rameses, olaf, interlinked,
# Nearest to freedom: torrens, harming, liberty, freedoms, libertarian, faire, pathogenic, purveyor,
# Nearest to instance: blazon, ritz, gawain, charybdis, turntable, pubic, quoting, arcology,
# Nearest to san: francisco, maranh, jose, marina, conservatorio, bunghole, narrows, angeles,
# Nearest to account: accounts, supposing, expedition, troop, discrepancies, occ, supercomputers, zero,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8374 0.2363 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8535 0.2242 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
